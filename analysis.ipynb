# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]'

# %%
print("Notebook is ready!")
# Out:
# Notebook is ready!

# %% [markdown]
# # CYB333 Final Project
# ## Password Strength Analyzer
# ### Gerardo Morales

# %%
import math

print("Environment OK")
print("Pi is:", math.pi)
# Out:
# Environment OK
# Pi is: 3.141592653589793

# %%
from password_analyzer import analyze_password

analyze_password("P@ssw0rd123")
# Out:
# {'password': 'P@ssw0rd123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 4,
#  'character_type_feedback': [],
#  'entropy': 3.28,
#  'total_score': 6}

# %%
from password_analyzer import analyze_password

analyze_password("123abc")
# Out:
# {'password': '123abc',
#  'length_score': 1,
#  'length_feedback': 'Password is too short (less than 8 characters).',
#  'character_type_score': 2,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing special character.'],
#  'entropy': 2.58,
#  'total_score': 3}

# %%
from password_analyzer import analyze_password

analyze_password("P@ssw0rd123")
# Out:
# {'password': 'P@ssw0rd123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 4,
#  'character_type_feedback': [],
#  'entropy': 3.28,
#  'dictionary_matches': [],
#  'total_score': 6}

# %%
from password_analyzer import analyze_password

analyze_password("P@ssw0rd123")
# Out:
# {'password': 'P@ssw0rd123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 4,
#  'character_type_feedback': [],
#  'entropy': 3.28,
#  'dictionary_matches': [],
#  'total_score': 6}

# %%
from password_analyzer import analyze_password

analyze_password("P@ssw0rd123")
# Out:
# {'password': 'P@ssw0rd123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 4,
#  'character_type_feedback': [],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'total_score': 6}

# %%
from password_analyzer import analyze_password

analyze_password("P@ssw0rd123")
# Out:
# {'password': 'P@ssw0rd123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 4,
#  'character_type_feedback': [],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'total_score': 6}

# %%
from password_analyzer import analyze_password

analyze_password("Password123")
# Out:
# {'password': 'Password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 3,
#  'character_type_feedback': ['Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': False,
#  'total_score': 5}

# %%
from password_analyzer import analyze_password

analyze_password("password")
# Out:
# {'password': 'password',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 1,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing digit.',
#   'Missing special character.'],
#  'entropy': 2.75,
#  'dictionary_matches': ['password'],
#  'is_common_password': True,
#  'total_score': 3}

# %%
from password_analyzer import analyze_password

analyze_password("Password123")
# Out:
# {'password': 'Password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 3,
#  'character_type_feedback': ['Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': False,
#  'total_score': 5}

# %%
from password_analyzer import analyze_password

analyze_password("Password123")
# Out:
# {'password': 'Password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 3,
#  'character_type_feedback': ['Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': False,
#  'total_score': 5}

# %%
from password_analyzer import analyze_password

analyze_password("qwerty")
# Out:
# {'password': 'qwerty',
#  'length_score': 1,
#  'length_feedback': 'Password is too short (less than 8 characters).',
#  'character_type_score': 1,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing digit.',
#   'Missing special character.'],
#  'entropy': 2.58,
#  'dictionary_matches': ['qwerty'],
#  'is_common_password': True,
#  'total_score': 2}

# %%
from password_analyzer import analyze_password

analyze_password("Password123")
# Out:
# {'password': 'Password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 3,
#  'character_type_feedback': ['Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': True,
#  'total_score': 5}

# %%
from password_analyzer import analyze_password

analyze_password("abc123")
# Out:
# {'password': 'abc123',
#  'length_score': 1,
#  'length_feedback': 'Password is too short (less than 8 characters).',
#  'character_type_score': 2,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing special character.'],
#  'entropy': 2.58,
#  'dictionary_matches': [],
#  'is_common_password': True,
#  'sequences_detected': ['123', 'abc'],
#  'repeated_characters': [],
#  'total_score': 3}

# %%
from password_analyzer import analyze_password

analyze_password("aaaabbbb")
# Out:
# {'password': 'aaaabbbb',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 1,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing digit.',
#   'Missing special character.'],
#  'entropy': 1.0,
#  'dictionary_matches': [],
#  'is_common_password': False,
#  'sequences_detected': [],
#  'repeated_characters': ['aaaa', 'bbbb'],
#  'total_score': 3}

# %%
from password_analyzer import analyze_password

analyze_password("qwerty99")
# Out:
# {'password': 'qwerty99',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 2,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing special character.'],
#  'entropy': 2.75,
#  'dictionary_matches': ['qwerty'],
#  'is_common_password': False,
#  'sequences_detected': ['qwe', 'wer', 'ert', 'rty'],
#  'repeated_characters': [],
#  'total_score': 4}

# %%
from password_analyzer import analyze_password

analyze_password("aaaabbbb")
# Out:
# {'password': 'aaaabbbb',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 1,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing digit.',
#   'Missing special character.'],
#  'entropy': 1.0,
#  'dictionary_matches': [],
#  'is_common_password': False,
#  'sequences_detected': [],
#  'repeated_characters': ['aaaa', 'bbbb'],
#  'total_score': 3}

# %%
try:
	from password_analyzer import analyze_password
except Exception as e:
	print("Failed to import analyze_password:", e)
	def analyze_password(pw):
		# simple fallback analyzer
		score = 0
		if any(c.islower() for c in pw): score += 1
		if any(c.isupper() for c in pw): score += 1
		if any(c.isdigit() for c in pw): score += 1
		if any(not c.isalnum() for c in pw): score += 1
		return {"password": pw, "score": score, "note": "fallback analyzer"}

print(analyze_password("Password123"))
# Out:
# {'password': 'Password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 3,
#  'character_type_feedback': ['Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': True,
#  'sequences_detected': ['123'],
#  'repeated_characters': [],
#  'recommendations': ['Consider increasing password length for stronger security.',
#   'Add at least one special character (e.g., !, @, #, $).',
#   'Avoid using dictionary words or common phrases.',
#   'This password is commonly used and easily guessed. Choose a more unique password.',
#   "Avoid sequential patterns like '123' or 'abc'.",
#   'Increase randomness to improve entropy.'],
#  'total_score': 5}

# %%
from password_analyzer import analyze_password_file

# %%
results = analyze_password_file("data/password_list.txt")
results
# Out:
# [{'password': 'Password123',
#   'length_score': 2,
#   'length_feedback': 'Password length is acceptable but could be stronger.',
#   'character_type_score': 3,
#   'character_type_feedback': ['Missing special character.'],
#   'entropy': 3.28,
#   'dictionary_matches': ['password'],
#   'is_common_password': True,
#   'sequences_detected': ['123'],
#   'repeated_characters': [],
#   'recommendations': ['Consider increasing password length for stronger security.',
#    'Add at least one special character (e.g., !, @, #, $).',
#    'Avoid using dictionary words or common phrases.',
#    'This password is commonly used and easily guessed. Choose a more unique password.',
#    "Avoid sequential patterns like '123' or 'abc'.",
#    'Increase randomness to improve entropy.'],
#   'total_score': 5},
#  {'password': '123456',
#   'length_score': 1,
#   'length_feedback': 'Password is too short (less than 8 characters).',
#   'character_type_score': 1,
#   'character_type_feedback': ['Missing uppercase letter.',
#    'Missing lowercase letter.',
#    'Missing special character.'],
#   'entropy': 2.58,
#   'dictionary_matches': [],
#   'is_common_password': True,
#   'sequences_detected': ['345', '234', '456', '123'],
#   'repeated_characters': [],
#   'recommendations': ['Increase password length to at least 12 characters.',
#    'Add at least one uppercase letter.',
#    'Add at least one lowercase letter.',
#    'Add at least one special character (e.g., !, @, #, $).',
#    'This password is commonly used and easily guessed. Choose a more unique password.',
#    "Avoid sequential patterns like '123' or 'abc'.",
#    'Increase randomness to improve entropy.'],
#   'total_score': 2},
#  {'password': 'Gm!92$kLq@7Z',
#   'length_score': 3,
#   'length_feedback': 'Password length is strong.',
#   'character_type_score': 4,
#   'character_type_feedback': [],
#   'entropy': 3.58,
#   'dictionary_matches': [],
#   'is_common_password': False,
#   'sequences_detected': [],
#   'repeated_characters': [],
#   'recommendations': ['Your password appears strong.'],
#   'total_score': 7},
#  {'password': 'qwerty',
#   'length_score': 1,
#   'length_feedback': 'Password is too short (less than 8 characters).',
#   'character_type_score': 1,
#   'character_type_feedback': ['Missing uppercase letter.',
#    'Missing digit.',
#    'Missing special character.'],
#   'entropy': 2.58,
#   'dictionary_matches': ['qwerty'],
#   'is_common_password': True,
#   'sequences_detected': ['ert', 'qwe', 'rty', 'wer'],
#   'repeated_characters': [],
#   'recommendations': ['Increase password length to at least 12 characters.',
#    'Add at least one uppercase letter.',
#    'Include at least one number.',
#    'Add at least one special character (e.g., !, @, #, $).',
#    'Avoid using dictionary words or common phrases.',
#    'This password is commonly used and easily guessed. Choose a more unique password.',
#    "Avoid sequential patterns like '123' or 'abc'.",
#    'Increase randomness to improve entropy.'],
#   'total_score': 2},
#  {'password': 'P@ssw0rd123',
#   'length_score': 2,
#   'length_feedback': 'Password length is acceptable but could be stronger.',
#   'character_type_score': 4,
#   'character_type_feedback': [],
#   'entropy': 3.28,
#   'dictionary_matches': ['password'],
#   'is_common_password': False,
#   'sequences_detected': ['123'],
#   'repeated_characters': [],
#   'recommendations': ['Consider increasing password length for stronger security.',
#    'Avoid using dictionary words or common phrases.',
#    "Avoid sequential patterns like '123' or 'abc'.",
#    'Increase randomness to improve entropy.'],
#   'total_score': 6},
#  {'password': 'letmein',
#   'length_score': 1,
#   'length_feedback': 'Password is too short (less than 8 characters).',
#   'character_type_score': 1,
#   'character_type_feedback': ['Missing uppercase letter.',
#    'Missing digit.',
#    'Missing special character.'],
#   'entropy': 2.52,
#   'dictionary_matches': ['letmein'],
#   'is_common_password': True,
#   'sequences_detected': [],
#   'repeated_characters': [],
#   'recommendations': ['Increase password length to at least 12 characters.',
#    'Add at least one uppercase letter.',
#    'Include at least one number.',
#    'Add at least one special character (e.g., !, @, #, $).',
#    'Avoid using dictionary words or common phrases.',
#    'This password is commonly used and easily guessed. Choose a more unique password.',
#    'Increase randomness to improve entropy.'],
#   'total_score': 2},
#  {'password': 'admin',
#   'length_score': 1,
#   'length_feedback': 'Password is too short (less than 8 characters).',
#   'character_type_score': 1,
#   'character_type_feedback': ['Missing uppercase letter.',
#    'Missing digit.',
#    'Missing special character.'],
#   'entropy': 2.32,
#   'dictionary_matches': ['admin'],
#   'is_common_password': True,
#   'sequences_detected': [],
#   'repeated_characters': [],
#   'recommendations': ['Increase password length to at least 12 characters.',
#    'Add at least one uppercase letter.',
#    'Include at least one number.',
#    'Add at least one special character (e.g., !, @, #, $).',
#    'Avoid using dictionary words or common phrases.',
#    'This password is commonly used and easily guessed. Choose a more unique password.',
#    'Increase randomness to improve entropy.'],
#   'total_score': 2}]

# %%
from password_analyzer import analyze_password

analyze_password("Password123")
# Out:
# {'password': 'Password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 3,
#  'character_type_feedback': ['Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': True,
#  'sequences_detected': ['123'],
#  'repeated_characters': [],
#  'recommendations': ['Consider increasing password length for stronger security.',
#   'Add at least one special character (e.g., !, @, #, $).',
#   'Avoid using dictionary words or common phrases.',
#   'This password is commonly used and easily guessed. Choose a more unique password.',
#   "Avoid sequential patterns like '123' or 'abc'.",
#   'Increase randomness to improve entropy.'],
#  'total_score': 5}

# %%
from password_analyzer import analyze_password

analyze_password("password123")
# Out:
# {'password': 'password123',
#  'length_score': 2,
#  'length_feedback': 'Password length is acceptable but could be stronger.',
#  'character_type_score': 2,
#  'character_type_feedback': ['Missing uppercase letter.',
#   'Missing special character.'],
#  'entropy': 3.28,
#  'dictionary_matches': ['password'],
#  'is_common_password': True,
#  'sequences_detected': ['123'],
#  'repeated_characters': [],
#  'recommendations': ['Consider increasing password length for stronger security.',
#   'Add at least one uppercase letter.',
#   'Add at least one special character (e.g., !, @, #, $).',
#   'Avoid using dictionary words or common phrases.',
#   'This password is commonly used and easily guessed. Choose a more unique password.',
#   "Avoid sequential patterns like '123' or 'abc'.",
#   'Increase randomness to improve entropy.'],
#  'strength_score': 0,
#  'total_score': 4}

# %%
from password_analyzer import analyze_password

analyze_password("Gm!92$kLq@7Z")
# Out:
# {'password': 'Gm!92$kLq@7Z',
#  'length_score': 3,
#  'length_feedback': 'Password length is strong.',
#  'character_type_score': 4,
#  'character_type_feedback': [],
#  'entropy': 3.58,
#  'dictionary_matches': [],
#  'is_common_password': False,
#  'sequences_detected': [],
#  'repeated_characters': [],
#  'recommendations': ['Your password appears strong.'],
#  'strength_score': 4,
#  'total_score': 7}
